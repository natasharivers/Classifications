# %%
import pandas as pd
import numpy as np
import os
from env import host, user, password
from pydataset import data
from acquire2 import new_titanic_data, new_iris_data, get_iris_data

# %%
get_iris_data()
# Out:
#      measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0                 1           5.1          3.5           1.4          0.2
# 1                 2           4.9          3.0           1.4          0.2
# 2                 3           4.7          3.2           1.3          0.2
# 3                 4           4.6          3.1           1.5          0.2
# 4                 5           5.0          3.6           1.4          0.2
# 5                 6           5.4          3.9           1.7          0.4
# 6                 7           4.6          3.4           1.4          0.3
# 7                 8           5.0          3.4           1.5          0.2
# 8                 9           4.4          2.9           1.4          0.2
# 9                10           4.9          3.1           1.5          0.1
# 10               11           5.4          3.7           1.5          0.2
# 11               12           4.8          3.4           1.6          0.2
# ...
