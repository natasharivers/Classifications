# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pydataset import data

# %% [markdown]
# ## Tidy Data Exercises

# %% [markdown]
# 1. Attendance Data
#
# - a. Load the attendance.csv file and
# - b. calculate an attendance percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.
#
# 2. Coffee Levels
#
# - a. Read the coffee_levels.csv file.
# - b. Transform the data so that each carafe is in it's own column.
# - c. Is this the best shape for the data?
#
# 3. Cake Recipes
#
# - a. Read the cake_recipes.csv data. This data set contains cake tastiness scores for combinations of different recipes, oven rack positions, and oven temperatures.
# - b. Tidy the data as necessary.
# - c. Which recipe, on average, is the best? recipe b
# - d. Which oven temperature, on average, produces the best results? 275
# - e. Which combination of recipe, rack position, and temperature gives the best result? recipe b, bottom rack, 300 degrees

# %% [markdown]
# #### 1a. Load the attendance.csv file

# %%
attendance = pd.read_csv('untidy-data/attendance.csv')

# %%
attendance.head()

# %%
sales.shape

# %%
attendance.info()

# %%
#melt data
attendance_melt= attendance.melt(id_vars='Unnamed: 0', var_name='date',value_name='attendance')
attendance_melt.head()
# Out:
#   Unnamed: 0        date attendance
# 0      Sally  2018-01-01          P
# 1       Jane  2018-01-01          A
# 2      Billy  2018-01-01          A
# 3       John  2018-01-01          P
# 4      Sally  2018-01-02          T

# %%
#rename column
attendance_melt = attendance_melt.rename(columns={'Unnamed: 0': 'name'})
attendance_melt.head()
# Out:
#     name        date attendance
# 0  Sally  2018-01-01          P
# 1   Jane  2018-01-01          A
# 2  Billy  2018-01-01          A
# 3   John  2018-01-01          P
# 4  Sally  2018-01-02          T

# %% [markdown]
# #### 1b. calculate an attendance percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.

# %%
#talk it out...
#p=1 = 100%
#a=0 = 0% absent
#t=.9 = 90% tardy/10=100, 1=.1
#h=.5 = 50% half day

# %%
#create function to turn letter grade into numeric grade
def attendance_percent(letter):
    if letter == 'P':
        return 1
    elif letter == 'A':
        return 0
    elif letter == 'T':
        return 0.9
    elif letter == 'H':
        return 0.5

# %%
#correct code to apply function: df['column']=df['column'].apply(function)
#turn letter grade into numeric
attendance_melt['attendance']=attendance_melt['attendance'].apply(attendance_percent)

# %%
attendance_melt.head()
# Out:
#     name        date  attendance
# 0  Sally  2018-01-01         1.0
# 1   Jane  2018-01-01         0.0
# 2  Billy  2018-01-01         0.0
# 3   John  2018-01-01         1.0
# 4  Sally  2018-01-02         0.9

# %%
#group by the name of the student to get average for each person
attendance_melt.groupby('name').attendance.mean()
# Out:
# name
# Billy    0.5250
# Jane     0.6875
# John     0.9125
# Sally    0.7625
# Name: attendance, dtype: float64

# %% [markdown]
# _________________________

# %% [markdown]
# #### 2a. Read the coffee_levels.csv file.

# %%
coffee = pd.read_csv('untidy-data/coffee_levels.csv')

# %%
#get to know data
coffee
# Out:
#     hour coffee_carafe  coffee_amount
# 0      8             x       0.816164
# 1      9             x       0.451018
# 2     10             x       0.843279
# 3     11             x       0.335533
# 4     12             x       0.898291
# 5     13             x       0.310711
# 6     14             x       0.507288
# 7     15             x       0.215043
# 8     16             x       0.183891
# 9     17             x       0.391560
# 10     8             y       0.189297
# 11     9             y       0.521502
# 12    10             y       0.023163
# 13    11             y       0.235529
# 14    12             y       0.017009
# 15    13             y       0.997464
# 16    14             y       0.058361
# 17    15             y       0.144644
# 18    16             y       0.544676
# 19    17             y       0.594126
# 20     8             z       0.999264
# 21     9             z       0.915990
# 22    10             z       0.144928
# 23    11             z       0.311495
# 24    12             z       0.771947
# 25    13             z       0.398520
# 26    14             z       0.864464
# 27    15             z       0.436364
# 28    16             z       0.280621
# 29    17             z       0.436677

# %% [markdown]
# #### 2b. Transform the data so that each carafe is in it's own column.

# %%
#pivot table
coffee.pivot_table(index=['hour'], columns='coffee_carafe', values = 'coffee_amount')
# Out:
# coffee_carafe         x         y         z
# hour
# 8              0.816164  0.189297  0.999264
# 9              0.451018  0.521502  0.915990
# 10             0.843279  0.023163  0.144928
# 11             0.335533  0.235529  0.311495
# 12             0.898291  0.017009  0.771947
# 13             0.310711  0.997464  0.398520
# 14             0.507288  0.058361  0.864464
# 15             0.215043  0.144644  0.436364
# 16             0.183891  0.544676  0.280621
# 17             0.391560  0.594126  0.436677

# %% [markdown]
# #### 2c. Is this the best shape for the data?

# %%
#yes. easier to read

# %% [markdown]
# _____________________

# %% [markdown]
# #### 3a. Read the cake_recipes.csv data.

# %%
cake = pd.read_csv('untidy-data/cake_recipes.csv')

# %%
cake
# Out:
#   recipe:position        225        250        275        300
# 0        a:bottom  61.738655  53.912627  74.414730  98.786784
# 1           a:top  51.709751  52.009735  68.576858  50.228470
# 2        b:bottom  57.095320  61.904369  61.196980  99.248541
# 3           b:top  82.455004  95.224151  98.594881  58.169349
# 4        c:bottom  96.470207  52.001358  92.893227  65.473084
# 5           c:top  71.306308  82.795477  92.098049  53.960273
# 6        d:bottom  52.799753  58.670419  51.747686  56.183110
# 7           d:top  96.873178  76.101363  59.571620  50.971626

# %%
cake.shape
# Out:
# (8, 5)

# %% [markdown]
# #### 3b. Tidy the data as necessary.

# %%
#rename recipe:position column
cake = cake.rename(columns={'recipe:position': 'delete'})
cake
# Out:
#      delete        225        250        275        300
# 0  a:bottom  61.738655  53.912627  74.414730  98.786784
# 1     a:top  51.709751  52.009735  68.576858  50.228470
# 2  b:bottom  57.095320  61.904369  61.196980  99.248541
# 3     b:top  82.455004  95.224151  98.594881  58.169349
# 4  c:bottom  96.470207  52.001358  92.893227  65.473084
# 5     c:top  71.306308  82.795477  92.098049  53.960273
# 6  d:bottom  52.799753  58.670419  51.747686  56.183110
# 7     d:top  96.873178  76.101363  59.571620  50.971626

# %%
cake.delete.str.split(':')
# Out:
# 0    [a, bottom]
# 1       [a, top]
# 2    [b, bottom]
# 3       [b, top]
# 4    [c, bottom]
# 5       [c, top]
# 6    [d, bottom]
# 7       [d, top]
# Name: delete, dtype: object

# %%
#split on : for recipe:position and create 2 new columns
#delete original column
cake[['recipe', 'position']] = cake.delete.str.split(':', expand = True)
cake
# Out:
#      delete        225        250        275        300 recipe position
# 0  a:bottom  61.738655  53.912627  74.414730  98.786784      a   bottom
# 1     a:top  51.709751  52.009735  68.576858  50.228470      a      top
# 2  b:bottom  57.095320  61.904369  61.196980  99.248541      b   bottom
# 3     b:top  82.455004  95.224151  98.594881  58.169349      b      top
# 4  c:bottom  96.470207  52.001358  92.893227  65.473084      c   bottom
# 5     c:top  71.306308  82.795477  92.098049  53.960273      c      top
# 6  d:bottom  52.799753  58.670419  51.747686  56.183110      d   bottom
# 7     d:top  96.873178  76.101363  59.571620  50.971626      d      top

# %%
#remove delete column
cake = cake.drop(columns='delete')
cake
# Out:
#          225        250        275        300 recipe position
# 0  61.738655  53.912627  74.414730  98.786784      a   bottom
# 1  51.709751  52.009735  68.576858  50.228470      a      top
# 2  57.095320  61.904369  61.196980  99.248541      b   bottom
# 3  82.455004  95.224151  98.594881  58.169349      b      top
# 4  96.470207  52.001358  92.893227  65.473084      c   bottom
# 5  71.306308  82.795477  92.098049  53.960273      c      top
# 6  52.799753  58.670419  51.747686  56.183110      d   bottom
# 7  96.873178  76.101363  59.571620  50.971626      d      top

# %%
#melt
cake_melt = cake.melt(id_vars=['recipe', 'position'], var_name='temp', value_name='score')
cake_melt
# Out:
#    recipe position temp      score
# 0       a   bottom  225  61.738655
# 1       a      top  225  51.709751
# 2       b   bottom  225  57.095320
# 3       b      top  225  82.455004
# 4       c   bottom  225  96.470207
# 5       c      top  225  71.306308
# 6       d   bottom  225  52.799753
# 7       d      top  225  96.873178
# 8       a   bottom  250  53.912627
# 9       a      top  250  52.009735
# 10      b   bottom  250  61.904369
# 11      b      top  250  95.224151
# 12      c   bottom  250  52.001358
# 13      c      top  250  82.795477
# 14      d   bottom  250  58.670419
# 15      d      top  250  76.101363
# 16      a   bottom  275  74.414730
# 17      a      top  275  68.576858
# 18      b   bottom  275  61.196980
# 19      b      top  275  98.594881
# 20      c   bottom  275  92.893227
# 21      c      top  275  92.098049
# 22      d   bottom  275  51.747686
# 23      d      top  275  59.571620
# 24      a   bottom  300  98.786784
# 25      a      top  300  50.228470
# 26      b   bottom  300  99.248541
# 27      b      top  300  58.169349
# 28      c   bottom  300  65.473084
# 29      c      top  300  53.960273
# 30      d   bottom  300  56.183110
# 31      d      top  300  50.971626

# %% [markdown]
# #### 3c. Which recipe, on average, is the best? recipe b

# %%
cake.mean(axis=1)
#b top
# Out:
# 0    72.213199
# 1    55.631204
# 2    69.861302
# 3    83.610846
# 4    76.709469
# 5    75.040027
# 6    54.850242
# 7    70.879447
# dtype: float64

# %%
#another way, using cake_melt
cake_melt.groupby('recipe').score.mean()
#answer:recipe b
# Out:
# recipe
# a    63.922201
# b    76.736074
# c    75.874748
# d    62.864844
# Name: score, dtype: float64

# %% [markdown]
# #### 3d. Which oven temperature, on average, produces the best results? 275

# %%
cake.mean(axis=0)
#275
# Out:
# 225    71.306022
# 250    66.577437
# 275    74.886754
# 300    66.627655
# dtype: float64

# %%
#another way, using cake_melt
cake_melt.groupby('temp').score.mean()
# Out:
# temp
# 225    71.306022
# 250    66.577437
# 275    74.886754
# 300    66.627655
# Name: score, dtype: float64

# %% [markdown]
# #### 3e. Which combination of recipe, rack position, and temperature gives the best result? recipe b, bottom rack, 300 degrees

# %%
#another way, using cake_melt
cake_melt['score'].max()
# Out:
# 99.2485405378462

# %%
cake_melt.sort_values(by='score').max()
# Out:
# recipe            d
# position        top
# temp            300
# score       99.2485
# dtype: object

# %%
cake_melt.sort_values(by='score').tail()
# Out:
#    recipe position temp      score
# 4       c   bottom  225  96.470207
# 7       d      top  225  96.873178
# 19      b      top  275  98.594881
# 24      a   bottom  300  98.786784
# 26      b   bottom  300  99.248541

# %% [markdown]
# _____

# %%
### Extra Practice:

# %%
gapminder = pd.read_csv('untidy-data/gapminder2.csv')

# %%
gapminder.head()
# Out:
#        country  life_expect_1955  life_expect_1960  life_expect_1965  \
# 0  Afghanistan            30.332            31.997            34.020
# 1    Argentina            64.399            65.142            65.634
# 2        Aruba            64.381            66.606            68.336
# 3    Australia            70.330            70.930            71.100
# 4      Austria            67.480            69.540            70.140
#
#    life_expect_1970  life_expect_1975  life_expect_1980  life_expect_1985  \
# 0            36.088            38.438            39.854            40.822
# 1            67.065            68.481            69.942            70.774
# 2            70.941            71.830            74.116            74.494
# 3            71.930            73.490            74.740            76.320
# 4            70.630            72.170            73.180            74.940
#
#    life_expect_1990  life_expect_1995  ...  pop_1960  pop_1965  pop_1970  \
# 0            41.674            41.763  ...   9829450  10997885  12430623
# 1            71.868            73.275  ...  20616009  22283100  23962313
# 2            74.108            73.011  ...     57203     59020     59039
# 3            77.560            78.830  ...  10361273  11439384  12660160
# 4            76.040            77.510  ...   7047437   7270889   7467086
#
#    pop_1975  pop_1980  pop_1985  pop_1990  pop_1995  pop_2000  pop_2005
# 0  14132019  15112149  13796928  14669339  20881480  23898198  29928987
# 1  26081880  28369799  30675059  33022202  35311049  37497728  39537943
# 2     59390     60266     64129     66653     67836     69539     71566
# 3  13771400  14615900  15788300  17022133  18116171  19164620  20090437
# 4   7578903   7549433   7559776   7722953   8047433   8113413   8184691
#
# [5 rows x 23 columns]

# %%
gapminder.columns
# Out:
# Index(['country', 'life_expect_1955', 'life_expect_1960', 'life_expect_1965',
#        'life_expect_1970', 'life_expect_1975', 'life_expect_1980',
#        'life_expect_1985', 'life_expect_1990', 'life_expect_1995',
#        'life_expect_2000', 'life_expect_2005', 'pop_1955', 'pop_1960',
#        'pop_1965', 'pop_1970', 'pop_1975', 'pop_1980', 'pop_1985', 'pop_1990',
#        'pop_1995', 'pop_2000', 'pop_2005'],
#       dtype='object')

# %%
gapminder_melt=gapminder.melt(id_vars='country')
gapminder_melt
# Out:
#              country          variable         value
# 0        Afghanistan  life_expect_1955  3.033200e+01
# 1          Argentina  life_expect_1955  6.439900e+01
# 2              Aruba  life_expect_1955  6.438100e+01
# 3          Australia  life_expect_1955  7.033000e+01
# 4            Austria  life_expect_1955  6.748000e+01
# ...              ...               ...           ...
# 1381     Switzerland          pop_2005  7.489370e+06
# 1382          Turkey          pop_2005  6.966056e+07
# 1383  United Kingdom          pop_2005  6.044146e+07
# 1384   United States          pop_2005  2.957341e+08
# 1385       Venezuela          pop_2005  2.537528e+07
#
# [1386 rows x 3 columns]

# %%
gapminder_pivot=gapminder.pivot_table(index='country')
gapminder_pivot.head()
# Out:
#              life_expect_1955  life_expect_1960  life_expect_1965  \
# country
# Afghanistan            30.332            31.997            34.020
# Argentina              64.399            65.142            65.634
# Aruba                  64.381            66.606            68.336
# Australia              70.330            70.930            71.100
# Austria                67.480            69.540            70.140
#
#              life_expect_1970  life_expect_1975  life_expect_1980  \
# country
# Afghanistan            36.088            38.438            39.854
# Argentina              67.065            68.481            69.942
# Aruba                  70.941            71.830            74.116
# Australia              71.930            73.490            74.740
# Austria                70.630            72.170            73.180
#
#              life_expect_1985  life_expect_1990  life_expect_1995  \
# country
# Afghanistan            40.822            41.674            41.763
# Argentina              70.774            71.868            73.275
# Aruba                  74.494            74.108            73.011
# Australia              76.320            77.560            78.830
# Austria                74.940            76.040            77.510
#
#              life_expect_2000  ...  pop_1960  pop_1965  pop_1970  pop_1975  \
# country                        ...
# Afghanistan            42.129  ...   9829450  10997885  12430623  14132019
# Argentina              74.340  ...  20616009  22283100  23962313  26081880
# Aruba                  73.451  ...     57203     59020     59039     59390
# Australia              80.370  ...  10361273  11439384  12660160  13771400
# Austria                78.980  ...   7047437   7270889   7467086   7578903
#
#              pop_1980  pop_1985  pop_1990  pop_1995  pop_2000  pop_2005
# country
# Afghanistan  15112149  13796928  14669339  20881480  23898198  29928987
# Argentina    28369799  30675059  33022202  35311049  37497728  39537943
# Aruba           60266     64129     66653     67836     69539     71566
# Australia    14615900  15788300  17022133  18116171  19164620  20090437
# Austria       7549433   7559776   7722953   8047433   8113413   8184691
#
# [5 rows x 22 columns]
